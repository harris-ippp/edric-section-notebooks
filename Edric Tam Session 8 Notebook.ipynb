# %% [markdown]
# ### Well done on Quiz Today
#     - apologies for typos for morning section
#
# ### This week's review (common mistakes and stuff relevant to this assignment)
# #### This assignment
#         - seems like many of you have questions ... **will try to keep review short and sweet and make Q & A longer today**
#         - beware of style
#         - REMEMBER ANSWERS.txt
#         - even if you can't scrape, can use the given csv file for pandas data analysis
#         - regular expression knowlege is useful for pandas analysis part
#
# #### webscraping demo
#         - step 1: look at website and see what information you want to scrape
#         - step 2: look at source code of website and find the unique tags/attributes that contains your information
#         - step 3: use BeautifulSoup to parse the pages
#         - step 4: Use BeautifulSoup functions or loops or regular expressions to save the information into useful data structures such as pandas dataframes for further analysis
#             - easiest way is to store a list of dictionaries, and then use pd.DataFrame() to convert to pandas dataframe format
#
# #### Regular Expressions (used in analysis part of assignment)
#         - Step 1: find out what patterns you want to match for
#         - Step 2: compile that pattern
#         - Step 3: feed a string to that pattern to find matches
#         - Most important regex patterns to know
#             - *
#             - d
#             - +
#             - ?
#             - \
#         - some useful regex functions:
#             - findall (don't confuse with BeautifulSoup's find_all)
#
# ####  Unicode Encodings
#         - right after you scrape, turn soup object into utf8 encoding
#         - should resolve issue
#         - this should be helpful for windows users alike
#         https://stackoverflow.com/questions/14630288/unicodeencodeerror-charmap-codec-cant-encode-character-maps-to-undefined?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa
#
# ### Q&A
#     - slido.com
#     - event code R466

# %%
# example link https://en.wikipedia.org/wiki/List_of_Nobel_laureates

### Standard boilerplate
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base = 'https://en.wikipedia.org'
path = '/wiki/List_of_Nobel_laureates'

response = requests.get(base + path)
page = BeautifulSoup(response.text, 'html.parser')

# %%
page.find_all("span", class_= "sortkey")
# Out:
# [<span class="sortkey">Röntgen, Wilhelm</span>,
#  <span class="sortkey">Hoff, Jacobus Henricus van 't</span>,
#  <span class="sortkey">von Behring, Emil Adolf</span>,
#  <span class="sortkey">Prudhomme, Sully</span>,
#  <span class="sortkey">Dunant, Henry</span>,
#  <span class="sortkey">Passy, Frédéric</span>,
#  <span class="sortkey">Lorentz, Hendrik</span>,
#  <span class="sortkey">Zeeman, Pieter</span>,
#  <span class="sortkey">Fischer, Hermann Emil</span>,
#  <span class="sortkey">Ross, Ronald</span>,
#  <span class="sortkey">Mommsen, Theodor</span>,
#  <span class="sortkey">Ducommun, Élie</span>,
#  <span class="sortkey">Gobat, Charles Albert</span>,
#  <span class="sortkey">Becquerel, Henri</span>,
#  <span class="sortkey">Curie, Pierre</span>,
#  <span class="sortkey">Curie, Marie</span>,
#  <span class="sortkey">Arrhenius, Svante</span>,
#  <span class="sortkey">Finsen, Niels Ryberg</span>,
#  <span class="sortkey">Bjørnson, Bjørnstjerne</span>,
#  <span class="sortkey">Cremer, Randal</span>,
#  <span class="sortkey">Rayleigh, Lord</span>,
#  <span class="sortkey">Ramsay, William</span>,
#  <span class="sortkey">Pavlov, Ivan</span>,
#  <span class="sortkey">Mistral, Frédéric</span>,
#  <span class="sortkey">Echegaray, José</span>,
#  <span class="sortkey">Lenard, Philipp</span>,
#  <span class="sortkey">Baeyer, Adolf von</span>,
#  <span class="sortkey">Koch, Robert</span>,
#  <span class="sortkey">Sienkiewicz, Henryk</span>,
#  <span class="sortkey">Suttner, Bertha von</span>,
#  <span class="sortkey">Thomson, J. J.</span>,
#  <span class="sortkey">Moissan, Henri</span>,
#  <span class="sortkey">Golgi, Camillo</span>,
#  <span class="sortkey">Ramón y Cajal, Santiago</span>,
#  <span class="sortkey">Carducci, Giosuè</span>,
#  <span class="sortkey">Roosevelt, Theodore</span>,
#  <span class="sortkey">Michelson, Albert Abraham</span>,
#  <span class="sortkey">Buchner, Eduard</span>,
#  <span class="sortkey">Laveran, Charles Louis Alphonse</span>,
#  <span class="sortkey">Kipling, Rudyard</span>,
#  <span class="sortkey">Moneta, Ernesto Teodoro</span>,
#  <span class="sortkey">Renault, Louis</span>,
#  <span class="sortkey">Lippmann, Gabriel</span>,
#  <span class="sortkey">Rutherford, Ernest</span>,
#  <span class="sortkey">Metchnikoff, Élie</span>,
#  <span class="sortkey">Ehrlich, Paul</span>,
#  <span class="sortkey">Eucken, Rudolf Christoph</span>,
#  <span class="sortkey">Arnoldson, Klas Pontus</span>,
#  <span class="sortkey">Bajer, Fredrik</span>,
#  <span class="sortkey">Braun, Karl Ferdinand</span>,
#  <span class="sortkey">Marconi, Guglielmo</span>,
#  <span class="sortkey">Ostwald, Wilhelm</span>,
#  <span class="sortkey">Kocher, Emil Theodor</span>,
#  <span class="sortkey">Lagerlöf, Selma</span>,
#  <span class="sortkey">Beernaert, Auguste Marie François</span>,
#  <span class="sortkey">d'Estournelles de Constant, Paul-Henri-Benjamin</span>,
#  <span class="sortkey">Waals, Johannes Diderik van der</span>,
#  <span class="sortkey">Wallach, Otto</span>,
#  <span class="sortkey">Kossel, Albrecht</span>,
#  <span class="sortkey">Heyse, Paul</span>,
#  <span class="sortkey">Wien, Wilhelm</span>,
#  <span class="sortkey">Skłodowska-Curie, Marie</span>,
#  <span class="sortkey">Gullstrand, Allvar</span>,
#  <span class="sortkey">Maeterlinck, Maurice</span>,
#  <span class="sortkey">Asser, Tobias</span>,
#  <span class="sortkey">Fried, Alfred Hermann</span>,
#  <span class="sortkey">Dalén, Gustaf</span>,
#  <span class="sortkey">Grignard, Victor</span>,
#  <span class="sortkey">Sabatier, Paul</span>,
#  <span class="sortkey">Carrel, Alexis</span>,
#  <span class="sortkey">Hauptmann, Gerhart</span>,
#  <span class="sortkey">Root, Elihu</span>,
#  <span class="sortkey">Kamerlingh Onnes, Heike</span>,
#  <span class="sortkey">Werner, Alfred</span>,
#  <span class="sortkey">Richet, Charles</span>,
#  <span class="sortkey">Tagore, Rabindranath</span>,
#  <span class="sortkey">La Fontaine, Henri</span>,
#  <span class="sortkey">von Laue, Max</span>,
#  <span class="sortkey">Richards, Theodore William</span>,
#  <span class="sortkey">Bárány, Robert</span>,
#  <span class="sortkey">Bragg, William Henry</span>,
#  <span class="sortkey">Bragg, William Lawrence</span>,
#  <span class="sortkey">Willstätter, Richard</span>,
#  <span class="sortkey">Rolland, Romain</span>,
#  <span class="sortkey">Heidenstam, Verner von</span>,
#  <span class="sortkey">Barkla, Charles Glover</span>,
#  <span class="sortkey">Gjellerup, Karl Adolph</span>,
#  <span class="sortkey">Pontoppidan, Henrik</span>,
#  <span class="sortkey">Planck, Max</span>,
#  <span class="sortkey">Haber, Fritz</span>,
#  <span class="sortkey">Stark, Johannes</span>,
#  <span class="sortkey">Bordet, Jules</span>,
#  <span class="sortkey">Spitteler, Carl</span>,
#  <span class="sortkey">Wilson, Woodrow</span>,
#  <span class="sortkey">Guillaume, Charles Édouard</span>,
#  <span class="sortkey">Nernst, Walther</span>,
#  <span class="sortkey">Krogh, August</span>,
#  <span class="sortkey">Hamsun, Knut</span>,
#  <span class="sortkey">Bourgeois, Léon</span>,
#  <span class="sortkey">Einstein, Albert</span>,
#  <span class="sortkey">Soddy, Frederick</span>,
#  <span class="sortkey">France, Anatole</span>,
#  <span class="sortkey">Branting, Hjalmar</span>,
#  <span class="sortkey">Lange, Christian Lous</span>,
#  <span class="sortkey">Bohr, Niels</span>,
#  <span class="sortkey">Aston, Francis William</span>,
#  <span class="sortkey">Hill, Archibald</span>,
#  <span class="sortkey">Meyerhof, Otto Fritz</span>,
#  <span class="sortkey">Benavente, Jacinto</span>,
#  <span class="sortkey">Nansen, Fridtjof</span>,
#  <span class="sortkey">Millikan, Robert Andrews</span>,
#  <span class="sortkey">Pregl, Fritz</span>,
#  <span class="sortkey">Banting, Frederick</span>,
#  <span class="sortkey">Macleod, John James Rickard</span>,
#  <span class="sortkey">Yeats, W. B.</span>,
#  <span class="sortkey">Siegbahn, Manne</span>,
#  <span class="sortkey">Einthoven, Willem</span>,
#  <span class="sortkey">Reymont, Władysław</span>,
#  <span class="sortkey">Franck, James</span>,
#  <span class="sortkey">Hertz, Gustav Ludwig</span>,
#  <span class="sortkey">Zsigmondy, Richard Adolf</span>,
#  <span class="sortkey">Shaw, George Bernard</span>,
#  <span class="sortkey">Chamberlain, Austen</span>,
#  <span class="sortkey">Dawes, Charles G.</span>,
#  <span class="sortkey">Perrin, Jean Baptiste</span>,
#  <span class="sortkey">Svedberg, Theodor</span>,
#  <span class="sortkey">Fibiger, Johannes</span>,
#  <span class="sortkey">Deledda, Grazia</span>,
#  <span class="sortkey">Briand, Aristide</span>,
#  <span class="sortkey">Stresemann, Gustav</span>,
#  <span class="sortkey">Compton, Arthur</span>,
#  <span class="sortkey">Wilson, Charles Thomson Rees</span>,
#  <span class="sortkey">Wieland, Heinrich Otto</span>,
#  <span class="sortkey">Wagner-Jauregg, Julius</span>,
#  <span class="sortkey">Bergson, Henri</span>,
#  <span class="sortkey">Buisson, Ferdinand</span>,
#  <span class="sortkey">Quidde, Ludwig</span>,
#  <span class="sortkey">Richardson, Owen Willans</span>,
#  <span class="sortkey">Windaus, Adolf Otto Reinhold</span>,
#  <span class="sortkey">Nicolle, Charles</span>,
#  <span class="sortkey">Undset, Sigrid</span>,
#  <span class="sortkey">Broglie, Louis de</span>,
#  <span class="sortkey">Harden, Arthur</span>,
#  <span class="sortkey">von Euler-Chelpin, Hans</span>,
#  <span class="sortkey">Eijkman, Christiaan</span>,
#  <span class="sortkey">Hopkins, Frederick Gowland</span>,
#  <span class="sortkey">Mann, Thomas</span>,
#  <span class="sortkey">Kellogg, Frank B.</span>,
#  <span class="sortkey">Raman, C. V.</span>,
#  <span class="sortkey">Fischer, Hans</span>,
#  <span class="sortkey">Landsteiner, Karl</span>,
#  <span class="sortkey">Lewis, Sinclair</span>,
#  <span class="sortkey">Söderblom, Nathan</span>,
#  <span class="sortkey">Bosch, Carl</span>,
#  <span class="sortkey">Bergius, Friedrich</span>,
#  <span class="sortkey">Warburg, Otto Heinrich</span>,
#  <span class="sortkey">Karlfeldt, Erik Axel</span>,
#  <span class="sortkey">Addams, Jane</span>,
#  <span class="sortkey">Butler, Nicholas Murray</span>,
#  <span class="sortkey">Heisenberg, Werner</span>,
#  <span class="sortkey">Langmuir, Irving</span>,
#  <span class="sortkey">Sherrington, Charles Scott</span>,
#  <span class="sortkey">Adrian, Edgar</span>,
#  <span class="sortkey">Galsworthy, John</span>,
#  <span class="sortkey">Schrödinger, Erwin</span>,
#  <span class="sortkey">Dirac, Paul</span>,
#  <span class="sortkey">Morgan, Thomas Hunt</span>,
#  <span class="sortkey">Bunin, Ivan</span>,
#  <span class="sortkey">Angell, Norman</span>,
#  <span class="sortkey">Urey, Harold</span>,
#  <span class="sortkey">Whipple, George</span>,
#  <span class="sortkey">Minot, George</span>,
#  <span class="sortkey">Murphy, William P.</span>,
#  <span class="sortkey">Pirandello, Luigi</span>,
#  <span class="sortkey">Henderson, Arthur</span>,
#  <span class="sortkey">Chadwick, James</span>,
#  <span class="sortkey">Joliot-Curie, Frédéric</span>,
#  <span class="sortkey">Joliot-Curie, Irène</span>,
#  <span class="sortkey">Spemann, Hans</span>,
#  <span class="sortkey">von Ossietzky, Carl</span>,
#  <span class="sortkey">Hess, Victor Francis</span>,
#  <span class="sortkey">Anderson, Carl David</span>,
#  <span class="sortkey">Debye, Peter</span>,
#  <span class="sortkey">Dale, Henry Hallett</span>,
#  <span class="sortkey">Loewi, Otto</span>,
#  <span class="sortkey">O'Neill, Eugene</span>,
#  <span class="sortkey">Lamas, Carlos Saavedra</span>,
#  <span class="sortkey">Davisson, Clinton</span>,
#  <span class="sortkey">Thomson, George Paget</span>,
#  <span class="sortkey">Haworth, Norman</span>,
#  <span class="sortkey">Karrer, Paul</span>,
#  <span class="sortkey">Szent-Györgyi, Albert</span>,
#  <span class="sortkey">du Gard, Roger Martin</span>,
#  <span class="sortkey">Cecil of Chelwood, The Viscount</span>,
#  <span class="sortkey">Fermi, Enrico</span>,
#  <span class="sortkey">Kuhn, Richard</span>,
#  <span class="sortkey">Heymans, Corneille</span>,
#  <span class="sortkey">Buck, Pearl S.</span>,
#  <span class="sortkey">Lawrence, Ernest</span>,
#  <span class="sortkey">Butenandt, Adolf</span>,
#  <span class="sortkey">Ružička, Leopold</span>,
#  <span class="sortkey">Domagk, Gerhard</span>,
#  <span class="sortkey">Sillanpää, Frans Eemil</span>,
#  <span class="sortkey">Stern, Otto</span>,
#  <span class="sortkey">Hevesy, George de</span>,
#  <span class="sortkey">Dam, Henrik</span>,
#  <span class="sortkey">Doisy, Edward Adelbert</span>,
#  <span class="sortkey">Rabi, Isidor Isaac</span>,
#  <span class="sortkey">Hahn, Otto</span>,
#  <span class="sortkey">Erlanger, Joseph</span>,
#  <span class="sortkey">Gasser, Herbert Spencer</span>,
#  <span class="sortkey">Jensen, Johannes Vilhelm</span>,
#  <span class="sortkey">Pauli, Wolfgang</span>,
#  <span class="sortkey">Virtanen, Artturi Ilmari</span>,
#  <span class="sortkey">Fleming, Alexander</span>,
#  <span class="sortkey">Chain, Ernst Boris</span>,
#  <span class="sortkey">Florey, Howard</span>,
#  <span class="sortkey">Mistral, Gabriela</span>,
#  <span class="sortkey">Hull, Cordell</span>,
#  <span class="sortkey">Bridgman, Percy Williams</span>,
#  <span class="sortkey">Sumner, James B.</span>,
#  <span class="sortkey">Northrop, John Howard</span>,
#  <span class="sortkey">Stanley, Wendell Meredith</span>,
#  <span class="sortkey">Muller, Hermann Joseph</span>,
#  <span class="sortkey">Hesse, Hermann</span>,
#  <span class="sortkey">Balch, Emily Greene</span>,
#  <span class="sortkey">Mott, John</span>,
#  <span class="sortkey">Appleton, Edward Victor</span>,
#  <span class="sortkey">Robinson, Robert</span>,
#  <span class="sortkey">Cori, Carl Ferdinand</span>,
#  <span class="sortkey">Cori, Gerty</span>,
#  <span class="sortkey">Houssay, Bernardo</span>,
#  <span class="sortkey">Gide, André</span>,
#  <span class="sortkey">Blackett, Patrick</span>,
#  <span class="sortkey">Tiselius, Arne</span>,
#  <span class="sortkey">Müller, Paul Hermann</span>,
#  <span class="sortkey">Eliot, T. S.</span>,
#  <span class="sortkey">Yukawa, Hideki</span>,
#  <span class="sortkey">Giauque, William</span>,
#  <span class="sortkey">Hess, Walter Rudolf</span>,
#  <span class="sortkey">Moniz, António Egas</span>,
#  <span class="sortkey">Faulkner, William</span>,
#  <span class="sortkey">Boyd Orr, John</span>,
#  <span class="sortkey">Powell, C. F.</span>,
#  <span class="sortkey">Diels, Otto</span>,
#  <span class="sortkey">Alder, Kurt</span>,
#  <span class="sortkey">Hench, Philip Showalter</span>,
#  <span class="sortkey">Kendall, Edward Calvin</span>,
#  <span class="sortkey">Reichstein, Tadeus</span>,
#  <span class="sortkey">Russell, Bertrand</span>,
#  <span class="sortkey">Bunche, Ralph</span>,
#  <span class="sortkey">Cockcroft, John</span>,
#  <span class="sortkey">Walton, Ernest</span>,
#  <span class="sortkey">McMillan, Edwin</span>,
#  <span class="sortkey">Seaborg, Glenn T.</span>,
#  <span class="sortkey">Theiler, Max</span>,
#  <span class="sortkey">Lagerkvist, Pär</span>,
#  <span class="sortkey">Jouhaux, Léon</span>,
#  <span class="sortkey">Bloch, Felix</span>,
#  <span class="sortkey">Purcell, Edward Mills</span>,
#  <span class="sortkey">Martin, Archer John Porter</span>,
#  <span class="sortkey">Synge, Richard Laurence Millington</span>,
#  <span class="sortkey">Waksman, Selman</span>,
#  <span class="sortkey">Mauriac, François</span>,
#  <span class="sortkey">Schweitzer, Albert</span>,
#  <span class="sortkey">Zernike, Frits</span>,
#  <span class="sortkey">Staudinger, Hermann</span>,
#  <span class="sortkey">Krebs, Hans Adolf</span>,
#  <span class="sortkey">Lipmann, Fritz Albert</span>,
#  <span class="sortkey">Churchill, Winston</span>,
#  <span class="sortkey">Marshall, George</span>,
#  <span class="sortkey">Born, Max</span>,
#  <span class="sortkey">Bothe, Walther</span>,
#  <span class="sortkey">Pauling, Linus</span>,
#  <span class="sortkey">Enders, John Franklin</span>,
#  <span class="sortkey">Robbins, Frederick Chapman</span>,
#  <span class="sortkey">Weller, Thomas Huckle</span>,
#  <span class="sortkey">Hemingway, Ernest</span>,
#  <span class="sortkey">Lamb, Willis</span>,
#  <span class="sortkey">Kusch, Polykarp</span>,
#  <span class="sortkey">du Vigneaud, Vincent</span>,
#  <span class="sortkey">Theorell, Hugo</span>,
#  <span class="sortkey">Laxness, Halldór</span>,
#  <span class="sortkey">Bardeen, John</span>,
#  <span class="sortkey">Brattain, Walter Houser</span>,
#  <span class="sortkey">Shockley, William</span>,
#  <span class="sortkey">Hinshelwood, Cyril Norman</span>,
#  <span class="sortkey">Semyonov, Nikolay</span>,
#  <span class="sortkey">Cournand, André Frédéric</span>,
#  <span class="sortkey">Forssmann, Werner</span>,
#  <span class="sortkey">Richards, Dickinson W.</span>,
#  <span class="sortkey">Jiménez, Juan Ramón</span>,
#  <span class="sortkey">Yang, Chen Ning</span>,
#  <span class="sortkey">Lee, Tsung-Dao</span>,
#  <span class="sortkey">Todd, The Lord</span>,
#  <span class="sortkey">Bovet, Daniel</span>,
#  <span class="sortkey">Camus, Albert</span>,
#  <span class="sortkey">Pearson, Lester B.</span>,
#  <span class="sortkey">Cherenkov, Pavel</span>,
#  <span class="sortkey">Frank, Ilya</span>,
#  <span class="sortkey">Tamm, Igor</span>,
#  <span class="sortkey">Sanger, Frederick</span>,
#  <span class="sortkey">Beadle, George Wells</span>,
#  <span class="sortkey">Tatum, Edward Lawrie</span>,
#  <span class="sortkey">Lederberg, Joshua</span>,
#  <span class="sortkey">Pasternak, Boris</span>,
#  <span class="sortkey">Pire, Dominique</span>,
#  <span class="sortkey">Segrè, Emilio G.</span>,
#  <span class="sortkey">Chamberlain, Owen</span>,
#  <span class="sortkey">Heyrovský, Jaroslav</span>,
#  <span class="sortkey">Kornberg, Arthur</span>,
#  <span class="sortkey">Ochoa, Severo</span>,
#  <span class="sortkey">Quasimodo, Salvatore</span>,
#  <span class="sortkey">Noel-Baker, Philip</span>,
#  <span class="sortkey">Glaser, Donald A.</span>,
#  <span class="sortkey">Libby, Willard</span>,
#  <span class="sortkey">Burnet, Frank Macfarlane</span>,
#  <span class="sortkey">Medawar, Peter</span>,
#  <span class="sortkey">Perse, Saint-John</span>,
#  <span class="sortkey">Lutuli, Albert</span>,
#  <span class="sortkey">Hofstadter, Robert</span>,
#  <span class="sortkey">Mössbauer, Rudolf</span>,
#  <span class="sortkey">Calvin, Melvin</span>,
#  <span class="sortkey">von Békésy, Georg</span>,
#  <span class="sortkey">Andrić, Ivo</span>,
#  <span class="sortkey">Hammarskjöld, Dag</span>,
#  <span class="sortkey">Landau, Lev</span>,
#  <span class="sortkey">Perutz, Max</span>,
#  <span class="sortkey">Kendrew, John</span>,
#  <span class="sortkey">Crick, Francis</span>,
#  <span class="sortkey">Watson, James D.</span>,
#  <span class="sortkey">Wilkins, Maurice</span>,
#  <span class="sortkey">Steinbeck, John</span>,
#  <span class="sortkey">Pauling, Linus</span>,
#  <span class="sortkey">Wigner, Eugene</span>,
#  <span class="sortkey">Goeppert-Mayer, Maria</span>,
#  <span class="sortkey">Jensen, J. Hans D.</span>,
#  <span class="sortkey">Ziegler, Karl</span>,
#  <span class="sortkey">Natta, Giulio</span>,
#  <span class="sortkey">Eccles, John</span>,
#  <span class="sortkey">Hodgkin, Alan Lloyd</span>,
#  <span class="sortkey">Huxley, Andrew</span>,
#  <span class="sortkey">Seferis, Giorgos</span>,
#  <span class="sortkey">Townes, Charles Hard</span>,
#  <span class="sortkey">Basov, Nikolay</span>,
#  <span class="sortkey">Prokhorov, Alexander</span>,
#  <span class="sortkey">Hodgkin, Dorothy</span>,
#  <span class="sortkey">Bloch, Konrad Emil</span>,
#  <span class="sortkey">Lynen, Feodor Felix Konrad</span>,
#  <span class="sortkey">Sartre, Jean-Paul</span>,
#  <span class="sortkey">King, Jr., Martin Luther</span>,
#  <span class="sortkey">Tomonaga, Sin-Itiro</span>,
#  <span class="sortkey">Schwinger, Julian</span>,
#  <span class="sortkey">Feynman, Richard</span>,
#  <span class="sortkey">Woodward, Robert Burns</span>,
#  <span class="sortkey">Jacob, François</span>,
#  <span class="sortkey">Lwoff, André Michel</span>,
#  <span class="sortkey">Monod, Jacques</span>,
#  <span class="sortkey">Sholokhov, Mikhail</span>,
#  <span class="sortkey">Kastler, Alfred</span>,
#  <span class="sortkey">Mulliken, Robert S.</span>,
#  <span class="sortkey">Rous, Francis Peyton</span>,
#  <span class="sortkey">Huggins, Charles Brenton</span>,
#  <span class="sortkey">Agnon, Shmuel Yosef</span>,
#  <span class="sortkey">Sachs, Nelly</span>,
#  <span class="sortkey">Bethe, Hans</span>,
#  <span class="sortkey">Eigen, Manfred</span>,
#  <span class="sortkey">Norrish, Ronald George Wreyford</span>,
#  <span class="sortkey">Porter, George</span>,
#  <span class="sortkey">Granit, Ragnar</span>,
#  <span class="sortkey">Hartline, Haldan Keffer</span>,
#  <span class="sortkey">Wald, George</span>,
#  <span class="sortkey">Asturias, Miguel Ángel</span>,
#  <span class="sortkey">Alvarez, Luis Walter</span>,
#  <span class="sortkey">Onsager, Lars</span>,
#  <span class="sortkey">Holley, Robert W.</span>,
#  <span class="sortkey">Khorana, Har Gobind</span>,
#  <span class="sortkey">Nirenberg, Marshall Warren</span>,
#  <span class="sortkey">Kawabata, Yasunari</span>,
#  <span class="sortkey">Cassin, René</span>,
#  <span class="sortkey">Gell-Mann, Murray</span>,
#  <span class="sortkey">Barton, Derek</span>,
#  <span class="sortkey">Hassel, Odd</span>,
#  <span class="sortkey">Delbrück, Max</span>,
#  <span class="sortkey">Hershey, Alfred</span>,
#  <span class="sortkey">Luria, Salvador</span>,
#  <span class="sortkey">Beckett, Samuel</span>,
#  <span class="sortkey">Frisch, Ragnar</span>,
#  <span class="sortkey">Tinbergen, Jan</span>,
#  <span class="sortkey">Alfvén, Hannes</span>,
#  <span class="sortkey">Néel, Louis</span>,
#  <span class="sortkey">Leloir, Luis Federico</span>,
#  <span class="sortkey">Axelrod, Julius</span>,
#  <span class="sortkey">von Euler, Ulf</span>,
#  <span class="sortkey">Katz, Bernard</span>,
#  <span class="sortkey">Solzhenitsyn, Aleksandr</span>,
#  <span class="sortkey">Borlaug, Norman</span>,
#  <span class="sortkey">Samuelson, Paul</span>,
#  <span class="sortkey">Gabor, Dennis</span>,
#  <span class="sortkey">Herzberg, Gerhard</span>,
#  <span class="sortkey">Sutherland, Jr., Earl Wilbur</span>,
#  <span class="sortkey">Neruda, Pablo</span>,
#  <span class="sortkey">Brandt, Willy</span>,
#  <span class="sortkey">Kuznets, Simon</span>,
#  <span class="sortkey">Bardeen, John</span>,
#  <span class="sortkey">Cooper, Leon</span>,
#  <span class="sortkey">Schrieffer, John Robert</span>,
#  <span class="sortkey">Anfinsen, Christian B.</span>,
#  <span class="sortkey">Moore, Stanford</span>,
#  <span class="sortkey">Stein, William Howard</span>,
#  <span class="sortkey">Edelman, Gerald</span>,
#  <span class="sortkey">Porter, Rodney Robert</span>,
#  <span class="sortkey">Böll, Heinrich</span>,
#  <span class="sortkey">Hicks, John</span>,
#  <span class="sortkey">Arrow, Kenneth</span>,
#  <span class="sortkey">Esaki, Leo</span>,
#  <span class="sortkey">Giaever, Ivar</span>,
#  <span class="sortkey">Josephson, Brian David</span>,
#  <span class="sortkey">Fischer, Ernst Otto</span>,
#  <span class="sortkey">Wilkinson, Geoffrey</span>,
#  <span class="sortkey">von Frisch, Karl</span>,
#  <span class="sortkey">Lorenz, Konrad</span>,
#  <span class="sortkey">Tinbergen, Nikolaas</span>,
#  <span class="sortkey">White, Patrick</span>,
#  <span class="sortkey">Kissinger, Henry</span>,
#  <span class="sortkey">Duc Tho, Le</span>,
#  <span class="sortkey">Leontief, Wassily</span>,
#  <span class="sortkey">Ryle, Martin</span>,
#  <span class="sortkey">Hewish, Antony</span>,
#  <span class="sortkey">Flory, Paul</span>,
#  <span class="sortkey">Claude, Albert</span>,
#  <span class="sortkey">de Duve, Christian</span>,
#  <span class="sortkey">Palade, George Emil</span>,
#  <span class="sortkey">Johnson, Eyvind</span>,
#  <span class="sortkey">Martinson, Harry</span>,
#  <span class="sortkey">MacBride, Seán</span>,
#  <span class="sortkey">Satō, Eisaku</span>,
#  <span class="sortkey">Myrdal, Gunnar</span>,
#  <span class="sortkey">Hayek, Friedrich</span>,
#  <span class="sortkey">Bohr, Aage</span>,
#  <span class="sortkey">Mottelson, Ben Roy</span>,
#  <span class="sortkey">Rainwater, James</span>,
#  <span class="sortkey">Cornforth, John</span>,
#  <span class="sortkey">Prelog, Vladimir</span>,
#  <span class="sortkey">Baltimore, David</span>,
#  <span class="sortkey">Dulbecco, Renato</span>,
#  <span class="sortkey">Temin, Howard Martin</span>,
#  <span class="sortkey">Montale, Eugenio</span>,
#  <span class="sortkey">Sakharov, Andrei</span>,
#  <span class="sortkey">Kantorovich, Leonid</span>,
#  <span class="sortkey">Koopmans, Tjalling</span>,
#  <span class="sortkey">Richter, Burton</span>,
#  <span class="sortkey">Ting, Samuel C. C.</span>,
#  <span class="sortkey">Lipscomb, William</span>,
#  <span class="sortkey">Blumberg, Baruch Samuel</span>,
#  <span class="sortkey">Gajdusek, Daniel Carleton</span>,
#  <span class="sortkey">Bellow, Saul</span>,
#  <span class="sortkey">Williams, Betty</span>,
#  <span class="sortkey">Maguire, Mairead</span>,
#  <span class="sortkey">Friedman, Milton</span>,
#  <span class="sortkey">Anderson, Philip Warren</span>,
#  <span class="sortkey">Mott, Nevill Francis</span>,
#  <span class="sortkey">Van Vleck, John Hasbrouck</span>,
#  <span class="sortkey">Prigogine, Ilya</span>,
#  <span class="sortkey">Guillemin, Roger</span>,
#  <span class="sortkey">Schally, Andrew</span>,
#  <span class="sortkey">Yalow, Rosalyn Sussman</span>,
#  <span class="sortkey">Aleixandre, Vicente</span>,
#  <span class="sortkey">Ohlin, Bertil</span>,
#  <span class="sortkey">Meade, James</span>,
#  <span class="sortkey">Kapitsa, Pyotr</span>,
#  <span class="sortkey">Penzias, Arno Allan</span>,
#  <span class="sortkey">Wilson, Robert Woodrow</span>,
#  <span class="sortkey">Mitchell, Peter D.</span>,
#  <span class="sortkey">Arber, Werner</span>,
#  <span class="sortkey">Nathans, Daniel</span>,
#  <span class="sortkey">Smith, Hamilton O.</span>,
#  <span class="sortkey">Singer, Isaac Bashevis</span>,
#  <span class="sortkey">Sadat, Anwar</span>,
#  <span class="sortkey">Begin, Menachem</span>,
#  <span class="sortkey">Simon, Herbert A.</span>,
#  <span class="sortkey">Glashow, Sheldon Lee</span>,
#  <span class="sortkey">Salam, Abdus</span>,
#  <span class="sortkey">Weinberg, Steven</span>,
#  <span class="sortkey">Brown, Herbert C.</span>,
#  <span class="sortkey">Wittig, Georg</span>,
#  <span class="sortkey">Cormack, Allan McLeod</span>,
#  <span class="sortkey">Hounsfield, Godfrey</span>,
#  <span class="sortkey">Elytis, Odysseas</span>,
#  <span class="sortkey">Teresa, Mother</span>,
#  <span class="sortkey">Schultz, Theodore</span>,
#  <span class="sortkey">Lewis, Arthur</span>,
#  <span class="sortkey">Cronin, James</span>,
#  <span class="sortkey">Fitch, Val Logsdon</span>,
#  <span class="sortkey">Berg, Paul</span>,
#  <span class="sortkey">Gilbert, Walter</span>,
#  <span class="sortkey">Sanger, Frederick</span>,
#  <span class="sortkey">Benacerraf, Baruj</span>,
#  <span class="sortkey">Dausset, Jean</span>,
#  <span class="sortkey">Snell, George Davis</span>,
#  <span class="sortkey">Miłosz, Czesław</span>,
#  <span class="sortkey">Esquivel, Adolfo Pérez</span>,
#  <span class="sortkey">Klein, Lawrence</span>,
#  <span class="sortkey">Bloembergen, Nicolaas</span>,
#  <span class="sortkey">Schawlow, Arthur Leonard</span>,
#  <span class="sortkey">Siegbahn, Kai</span>,
#  <span class="sortkey">Fukui, Kenichi</span>,
#  <span class="sortkey">Hoffmann, Roald</span>,
#  <span class="sortkey">Sperry, Roger Wolcott</span>,
#  <span class="sortkey">Hubel, David H.</span>,
#  <span class="sortkey">Wiesel, Torsten</span>,
#  <span class="sortkey">Canetti, Elias</span>,
#  <span class="sortkey">Tobin, James</span>,
#  <span class="sortkey">Wilson, Kenneth G.</span>,
#  <span class="sortkey">Klug, Aaron</span>,
#  <span class="sortkey">Bergström, Sune</span>,
#  <span class="sortkey">Samuelsson, Bengt I.</span>,
#  <span class="sortkey">Vane, John</span>,
#  <span class="sortkey">Márquez, Gabriel García</span>,
#  <span class="sortkey">Myrdal, Alva</span>,
#  <span class="sortkey">Robles, Alfonso García</span>,
#  <span class="sortkey">Stigler, George</span>,
#  <span class="sortkey">Chandrasekhar, Subrahmanyan</span>,
#  <span class="sortkey">Fowler, William Alfred</span>,
#  <span class="sortkey">Taube, Henry</span>,
#  <span class="sortkey">McClintock, Barbara</span>,
#  <span class="sortkey">Golding, William</span>,
#  <span class="sortkey">Wałęsa, Lech</span>,
#  <span class="sortkey">Debreu, Gérard</span>,
#  <span class="sortkey">Rubbia, Carlo</span>,
#  <span class="sortkey">van der Meer, Simon</span>,
#  <span class="sortkey">Merrifield, Robert Bruce</span>,
#  <span class="sortkey">Jerne, Niels Kaj</span>,
#  <span class="sortkey">Köhler, Georges J. F.</span>,
#  <span class="sortkey">Milstein, César</span>,
#  <span class="sortkey">Seifert, Jaroslav</span>,
#  <span class="sortkey">Tutu, Desmond</span>,
#  <span class="sortkey">Stone, Richard</span>,
#  <span class="sortkey">von Klitzing, Klaus</span>,
#  <span class="sortkey">Hauptman, Herbert A.</span>,
#  <span class="sortkey">Karle, Jerome</span>,
#  <span class="sortkey">Brown, Michael Stuart</span>,
#  <span class="sortkey">Goldstein, Joseph L.</span>,
#  <span class="sortkey">Simon, Claude</span>,
#  <span class="sortkey">Modigliani, Franco</span>,
#  <span class="sortkey">Ruska, Ernst</span>,
#  <span class="sortkey">Binnig, Gerd</span>,
#  <span class="sortkey">Rohrer, Heinrich</span>,
#  <span class="sortkey">Herschbach, Dudley R.</span>,
#  <span class="sortkey">Lee, Yuan T.</span>,
#  <span class="sortkey">Polanyi, John</span>,
#  <span class="sortkey">Cohen, Stanley</span>,
#  <span class="sortkey">Levi-Montalcini, Rita</span>,
#  <span class="sortkey">Soyinka, Wole</span>,
#  <span class="sortkey">Wiesel, Elie</span>,
#  <span class="sortkey">Buchanan, James M.</span>,
#  <span class="sortkey">Bednorz, Johannes Georg</span>,
#  <span class="sortkey">Müller, Karl Alexander</span>,
#  <span class="sortkey">Cram, Donald J.</span>,
#  <span class="sortkey">Lehn, Jean-Marie</span>,
#  <span class="sortkey">Pedersen, Charles J.</span>,
#  <span class="sortkey">Tonegawa, Susumu</span>,
#  <span class="sortkey">Brodsky, Joseph</span>,
#  <span class="sortkey">Arias, Óscar</span>,
#  <span class="sortkey">Solow, Robert</span>,
#  <span class="sortkey">Lederman, Leon M.</span>,
#  <span class="sortkey">Schwartz, Melvin</span>,
#  <span class="sortkey">Steinberger, Jack</span>,
#  <span class="sortkey">Deisenhofer, Johann</span>,
#  <span class="sortkey">Huber, Robert</span>,
#  <span class="sortkey">Michel, Hartmut</span>,
#  <span class="sortkey">Black, James W.</span>,
#  <span class="sortkey">Elion, Gertrude B.</span>,
#  <span class="sortkey">Hitchings, George H.</span>,
#  <span class="sortkey">Mahfouz, Naguib</span>,
#  <span class="sortkey">Allais, Maurice</span>,
#  <span class="sortkey">Ramsey, Jr., Norman Foster</span>,
#  <span class="sortkey">Dehmelt, Hans Georg</span>,
#  <span class="sortkey">Paul, Wolfgang</span>,
#  <span class="sortkey">Altman, Sidney</span>,
#  <span class="sortkey">Cech, Thomas</span>,
#  <span class="sortkey">Bishop, J. Michael</span>,
#  <span class="sortkey">Varmus, Harold E.</span>,
#  <span class="sortkey">Cela, Camilo José</span>,
#  <span class="sortkey">Gyatso (The 14th Dalai Lama), Tenzin</span>,
#  <span class="sortkey">Haavelmo, Trygve</span>,
#  <span class="sortkey">Friedman, Jerome Isaac</span>,
#  <span class="sortkey">Kendall, Henry Way</span>,
#  <span class="sortkey">Taylor, Richard E.</span>,
#  <span class="sortkey">Corey, Elias James</span>,
#  <span class="sortkey">Murray, Joseph</span>,
#  <span class="sortkey">Thomas, E. Donnall</span>,
#  <span class="sortkey">Paz, Octavio</span>,
#  <span class="sortkey">Gorbachev, Mikhail</span>,
#  <span class="sortkey">Markowitz, Harry</span>,
#  <span class="sortkey">Miller, Merton</span>,
#  <span class="sortkey">Sharpe, William F.</span>,
#  <span class="sortkey">Gennes, Pierre-Gilles de</span>,
#  <span class="sortkey">Ernst, Richard R.</span>,
#  <span class="sortkey">Neher, Erwin</span>,
#  <span class="sortkey">Sakmann, Bert</span>,
#  <span class="sortkey">Gordimer, Nadine</span>,
#  <span class="sortkey">Suu Kyi, Aung San</span>,
#  <span class="sortkey">Coase, Ronald</span>,
#  <span class="sortkey">Charpak, Georges</span>,
#  <span class="sortkey">Marcus, Rudolph A.</span>,
#  <span class="sortkey">Fischer, Edmond H.</span>,
#  <span class="sortkey">Krebs, Edwin G.</span>,
#  <span class="sortkey">Walcott, Derek</span>,
#  <span class="sortkey">Menchú, Rigoberta</span>,
#  <span class="sortkey">Becker, Gary</span>,
#  <span class="sortkey">Hulse, Russell Alan</span>,
#  <span class="sortkey">Taylor, Jr., Joseph Hooton</span>,
#  <span class="sortkey">Mullis, Kary</span>,
#  <span class="sortkey">Smith, Michael</span>,
#  <span class="sortkey">Roberts, Richard J.</span>,
#  <span class="sortkey">Sharp, Phillip Allen</span>,
#  <span class="sortkey">Morrison, Toni</span>,
#  <span class="sortkey">Mandela, Nelson</span>,
#  <span class="sortkey">de Klerk, F. W.</span>,
#  <span class="sortkey">Fogel, Robert</span>,
#  <span class="sortkey">North, Douglass</span>,
#  <span class="sortkey">Brockhouse, Bertram</span>,
#  <span class="sortkey">Shull, Clifford</span>,
#  <span class="sortkey">Olah, George Andrew</span>,
#  <span class="sortkey">Gilman, Alfred G.</span>,
#  <span class="sortkey">Rodbell, Martin</span>,
#  <span class="sortkey">Ōe, Kenzaburō</span>,
#  <span class="sortkey">Arafat, Yasser</span>,
#  <span class="sortkey">Peres, Shimon</span>,
#  <span class="sortkey">Rabin, Yitzhak</span>,
#  <span class="sortkey">Harsanyi, John</span>,
#  <span class="sortkey">Nash, Jr., John Forbes</span>,
#  <span class="sortkey">Selten, Reinhard</span>,
#  <span class="sortkey">Perl, Martin Lewis</span>,
#  <span class="sortkey">Reines, Frederick</span>,
#  <span class="sortkey">Crutzen, Paul J.</span>,
#  <span class="sortkey">Molina, Mario J.</span>,
#  <span class="sortkey">Rowland, Frank Sherwood</span>,
#  <span class="sortkey">Lewis, Edward B.</span>,
#  <span class="sortkey">Nüsslein-Volhard, Christiane</span>,
#  <span class="sortkey">Wieschaus, Eric F.</span>,
#  <span class="sortkey">Heaney, Seamus</span>,
#  <span class="sortkey">Rotblat, Joseph</span>,
#  <span class="sortkey">Lucas, Jr., Robert</span>,
#  <span class="sortkey">Lee, David</span>,
#  <span class="sortkey">Osheroff, Douglas</span>,
#  <span class="sortkey">Richardson, Robert Coleman</span>,
#  <span class="sortkey">Curl Jr., Robert F.</span>,
#  <span class="sortkey">Kroto, Harry</span>,
#  <span class="sortkey">Smalley, Richard</span>,
#  <span class="sortkey">Doherty, Peter C.</span>,
#  <span class="sortkey">Zinkernagel, Rolf M.</span>,
#  <span class="sortkey">Szymborska, Wisława</span>,
#  <span class="sortkey">Belo, Carlos Filipe Ximenes</span>,
#  <span class="sortkey">Ramos-Horta, José</span>,
#  <span class="sortkey">Mirrlees, James</span>,
#  <span class="sortkey">Vickrey, William</span>,
#  <span class="sortkey">Chu, Steven</span>,
#  <span class="sortkey">Cohen-Tannoudji, Claude</span>,
#  <span class="sortkey">Phillips, William Daniel</span>,
#  <span class="sortkey">Boyer, Paul D.</span>,
#  <span class="sortkey">Walker, John E.</span>,
#  <span class="sortkey">Skou, Jens Christian</span>,
#  <span class="sortkey">Prusiner, Stanley B.</span>,
#  <span class="sortkey">Fo, Dario</span>,
#  <span class="sortkey">Williams, Jody</span>,
#  <span class="sortkey">Merton, Robert C.</span>,
#  <span class="sortkey">Scholes, Myron</span>,
#  <span class="sortkey">Laughlin, Robert B.</span>,
#  <span class="sortkey">Störmer, Horst Ludwig</span>,
#  <span class="sortkey">Tsui, Daniel C.</span>,
#  <span class="sortkey">Kohn, Walter</span>,
#  <span class="sortkey">Pople, John</span>,
#  <span class="sortkey">Furchgott, Robert F.</span>,
#  <span class="sortkey">Ignarro, Louis</span>,
#  <span class="sortkey">Murad, Ferid</span>,
#  <span class="sortkey">Saramago, José</span>,
#  <span class="sortkey">Hume, John</span>,
#  <span class="sortkey">Trimble, David</span>,
#  <span class="sortkey">Sen, Amartya</span>,
#  <span class="sortkey">Hooft, Gerard 't</span>,
#  <span class="sortkey">Veltman, Martinus J. G.</span>,
#  <span class="sortkey">Zewail, Ahmed</span>,
#  <span class="sortkey">Blobel, Günter</span>,
#  <span class="sortkey">Grass, Günter</span>,
#  <span class="sortkey">Mundell, Robert</span>,
#  <span class="sortkey">Alferov, Zhores</span>,
#  <span class="sortkey">Kroemer, Herbert</span>,
#  <span class="sortkey">Kilby, Jack</span>,
#  <span class="sortkey">Heeger, Alan J.</span>,
#  <span class="sortkey">MacDiarmid, Alan</span>,
#  <span class="sortkey">Shirakawa, Hideki</span>,
#  <span class="sortkey">Carlsson, Arvid</span>,
#  <span class="sortkey">Greengard, Paul</span>,
#  <span class="sortkey">Kandel, Eric</span>,
#  <span class="sortkey">Xingjian, Gao</span>,
#  <span class="sortkey">Dae-jung, Kim</span>,
#  <span class="sortkey">Heckman, James</span>,
#  <span class="sortkey">McFadden, Daniel</span>,
#  <span class="sortkey">Cornell, Eric Allin</span>,
#  <span class="sortkey">Ketterle, Wolfgang</span>,
#  <span class="sortkey">Wieman, Carl</span>,
#  <span class="sortkey">Knowles, William Standish</span>,
#  <span class="sortkey">Noyori, Ryōji</span>,
#  <span class="sortkey">Sharpless, Karl Barry</span>,
#  <span class="sortkey">Hartwell, Leland H.</span>,
#  <span class="sortkey">Hunt, Tim</span>,
#  <span class="sortkey">Nurse, Paul</span>,
#  <span class="sortkey">Naipaul, V. S.</span>,
#  <span class="sortkey">Annan, Kofi</span>,
#  <span class="sortkey">Akerlof, George</span>,
#  <span class="sortkey">Spence, Michael</span>,
#  <span class="sortkey">Stiglitz, Joseph</span>,
#  <span class="sortkey">Davis, Jr., Raymond</span>,
#  <span class="sortkey">Koshiba, Masatoshi</span>,
#  <span class="sortkey">Giacconi, Riccardo</span>,
#  <span class="sortkey">Fenn, John</span>,
#  <span class="sortkey">Tanaka, Koichi</span>,
#  <span class="sortkey">Wüthrich, Kurt</span>,
#  <span class="sortkey">Brenner, Sydney</span>,
#  <span class="sortkey">Horvitz, H. Robert</span>,
#  <span class="sortkey">Sulston, John</span>,
#  <span class="sortkey">Kertész, Imre</span>,
#  <span class="sortkey">Carter, Jimmy</span>,
#  <span class="sortkey">Kahneman, Daniel</span>,
#  <span class="sortkey">Smith, Vernon L.</span>,
#  <span class="sortkey">Abrikosov, Alexei Alexeyevich</span>,
#  <span class="sortkey">Ginzburg, Vitaly</span>,
#  <span class="sortkey">Leggett, Anthony James</span>,
#  <span class="sortkey">Agre, Peter</span>,
#  <span class="sortkey">MacKinnon, Roderick</span>,
#  <span class="sortkey">Lauterbur, Paul</span>,
#  <span class="sortkey">Mansfield, Peter</span>,
#  <span class="sortkey">Coetzee, J. M.</span>,
#  <span class="sortkey">Ebadi, Shirin</span>,
#  <span class="sortkey">Engle, Robert F.</span>,
#  <span class="sortkey">Granger, Clive</span>,
#  <span class="sortkey">Gross, David</span>,
#  <span class="sortkey">Politzer, Hugh David</span>,
#  <span class="sortkey">Wilczek, Frank</span>,
#  <span class="sortkey">Ciechanover, Aaron</span>,
#  <span class="sortkey">Hershko, Avram</span>,
#  <span class="sortkey">Rose, Irwin</span>,
#  <span class="sortkey">Axel, Richard</span>,
#  <span class="sortkey">Buck, Linda B.</span>,
#  <span class="sortkey">Jelinek, Elfriede</span>,
#  <span class="sortkey">Maathai, Wangari</span>,
#  <span class="sortkey">Kydland, Finn E.</span>,
#  <span class="sortkey">Prescott, Edward C.</span>,
#  <span class="sortkey">Glauber, Roy J.</span>,
#  <span class="sortkey">Hall, John L.</span>,
#  <span class="sortkey">Hänsch, Theodor W.</span>,
#  <span class="sortkey">Chauvin, Yves</span>,
#  <span class="sortkey">Grubbs, Robert H.</span>,
#  <span class="sortkey">Schrock, Richard R.</span>,
#  <span class="sortkey">Marshall, Barry</span>,
#  <span class="sortkey">Warren, Robin</span>,
#  <span class="sortkey">Pinter, Harold</span>,
#  <span class="sortkey">ElBaradei, Mohamed</span>,
#  <span class="sortkey">Aumann, Robert</span>,
#  <span class="sortkey">Schelling, Thomas</span>,
#  <span class="sortkey">Mather, John C.</span>,
#  <span class="sortkey">Smoot, George</span>,
#  <span class="sortkey">Kornberg, Roger D.</span>,
#  <span class="sortkey">Fire, Andrew</span>,
#  <span class="sortkey">Mello, Craig</span>,
#  <span class="sortkey">Pamuk, Orhan</span>,
#  <span class="sortkey">Yunus, Muhammad</span>,
#  <span class="sortkey">Phelps, Edmund</span>,
#  <span class="sortkey">Fert, Albert</span>,
#  <span class="sortkey">Grünberg, Peter</span>,
#  <span class="sortkey">Ertl, Gerhard</span>,
#  <span class="sortkey">Capecchi, Mario</span>,
#  <span class="sortkey">Evans, Martin</span>,
#  <span class="sortkey">Smithies, Oliver</span>,
#  <span class="sortkey">Lessing, Doris</span>,
#  <span class="sortkey">Gore, Al</span>,
#  <span class="sortkey">Hurwicz, Leonid</span>,
#  <span class="sortkey">Maskin, Eric</span>,
#  <span class="sortkey">Myerson, Roger</span>,
#  <span class="sortkey">Nambu, Yoichiro</span>,
#  <span class="sortkey">Kobayashi, Makoto</span>,
#  <span class="sortkey">Maskawa, Toshihide</span>,
#  <span class="sortkey">Shimomura, Osamu</span>,
#  <span class="sortkey">Chalfie, Martin</span>,
#  <span class="sortkey">Tsien, Roger Y.</span>,
#  <span class="sortkey">zur Hausen, Harald</span>,
#  <span class="sortkey">Barré-Sinoussi, Françoise</span>,
#  <span class="sortkey">Montagnier, Luc</span>,
#  <span class="sortkey">Le Clézio, J. M. G.</span>,
#  <span class="sortkey">Ahtisaari, Martti</span>,
#  <span class="sortkey">Krugman, Paul</span>,
#  <span class="sortkey">Kao, Charles K.</span>,
#  <span class="sortkey">Boyle, Willard S.</span>,
#  <span class="sortkey">Smith, George E.</span>,
#  <span class="sortkey">Ramakrishnan, Venkatraman</span>,
#  <span class="sortkey">Steitz, Thomas A.</span>,
#  <span class="sortkey">Yonath, Ada</span>,
#  <span class="sortkey">Blackburn, Elizabeth</span>,
#  <span class="sortkey">Greider, Carol W.</span>,
#  <span class="sortkey">Szostak, Jack W.</span>,
#  <span class="sortkey">Müller, Herta</span>,
#  <span class="sortkey">Obama, Barack</span>,
#  <span class="sortkey">Ostrom, Elinor</span>,
#  <span class="sortkey">Williamson, Oliver E.</span>,
#  <span class="sortkey">Geim, Andre</span>,
#  <span class="sortkey">Novoselov, Konstantin</span>,
#  <span class="sortkey">Heck, Richard F.</span>,
#  <span class="sortkey">Negishi, Ei-ichi</span>,
#  <span class="sortkey">Suzuki, Akira</span>,
#  <span class="sortkey">Edwards, Robert G.</span>,
#  <span class="sortkey">Vargas Llosa, Mario</span>,
#  <span class="sortkey">Xiaobo, Liu</span>,
#  <span class="sortkey">Diamond, Peter A.</span>,
#  <span class="sortkey">Mortensen, Dale T.</span>,
#  <span class="sortkey">Pissarides, Christopher A.</span>,
#  <span class="sortkey">Perlmutter, Saul</span>,
#  <span class="sortkey">Riess, Adam G.</span>,
#  <span class="sortkey">Schmidt, Brian</span>,
#  <span class="sortkey">Shechtman, Dan</span>,
#  <span class="sortkey">Beutler, Bruce</span>,
#  <span class="sortkey">Hoffmann, Jules A.</span>,
#  <span class="sortkey">Steinman, Ralph M.</span>,
#  <span class="sortkey">Tranströmer, Tomas</span>,
#  <span class="sortkey">Sirleaf, Ellen Johnson</span>,
#  <span class="sortkey">Gbowee, Leymah</span>,
#  <span class="sortkey">Karman, Tawakel</span>,
#  <span class="sortkey">Sargent, Thomas J.</span>,
#  <span class="sortkey">Sims, Christopher A.</span>,
#  <span class="sortkey">Haroche, Serge</span>,
#  <span class="sortkey">J. Wineland, David</span>,
#  <span class="sortkey">Kobilka, Brian K.</span>,
#  <span class="sortkey">Lefkowitz, Robert J.</span>,
#  <span class="sortkey">Gurdon, John B.</span>,
#  <span class="sortkey">Yamanaka, Shinya</span>,
#  <span class="sortkey">Yan, Mo</span>,
#  <span class="sortkey">Union, European</span>,
#  <span class="sortkey">Roth, Alvin E.</span>,
#  <span class="sortkey">Shapley, Lloyd S.</span>,
#  <span class="sortkey">Englert, François</span>,
#  <span class="sortkey">Higgs, Peter W.</span>,
#  <span class="sortkey">Karplus, Martin</span>,
#  <span class="sortkey">Levitt, Michael</span>,
#  <span class="sortkey">Warshel, Arieh</span>,
#  <span class="sortkey">Rothman, James E.</span>,
#  <span class="sortkey">Schekman, Randy W.</span>,
#  <span class="sortkey">Südhof, Thomas C.</span>,
#  <span class="sortkey">Munro, Alice</span>,
#  <span class="sortkey">for the Prohibition of Chemical Weapons, Organisation</span>,
#  <span class="sortkey">Fama, Eugene F.</span>,
#  <span class="sortkey">Hansen, Lars Peter</span>,
#  <span class="sortkey">Shiller, Robert J.</span>,
#  <span class="sortkey">Akasaki, Isamu</span>,
#  <span class="sortkey">Amano, Hiroshi</span>,
#  <span class="sortkey">Nakamura, Shuji</span>,
#  <span class="sortkey">Betzig, Eric</span>,
#  <span class="sortkey">Hell, Stefan</span>,
#  <span class="sortkey">Moerner, William</span>,
#  <span class="sortkey">O'Keefe, John</span>,
#  <span class="sortkey">Moser, May-Britt</span>,
#  <span class="sortkey">Moser, Edvard</span>,
#  <span class="sortkey">Modiano, Patrick</span>,
#  <span class="sortkey">Satyarthi, Kailash</span>,
#  <span class="sortkey">Yousafzai, Malala</span>,
#  <span class="sortkey">Tirole, Jean</span>,
#  <span class="sortkey">Kajita, Takaaki</span>,
#  <span class="sortkey">McDonald, Arthur B.</span>,
#  <span class="sortkey">Lindahl, Tomas</span>,
#  <span class="sortkey">Modrich, Paul L.</span>,
#  <span class="sortkey">Sancar, Aziz</span>,
#  <span class="sortkey">Campbell, William C.</span>,
#  <span class="sortkey">Ōmura, Satoshi</span>,
#  <span class="sortkey">Youyou, Tu</span>,
#  <span class="sortkey">Alexievich, Svetlana</span>,
#  <span class="sortkey">National Dialogue Quartet, Tunisian</span>,
#  <span class="sortkey">Deaton, Angus</span>,
#  <span class="sortkey">J. Thouless, David</span>,
#  <span class="sortkey">Haldane, Duncan</span>,
#  <span class="sortkey">Kosterlitz, John M.</span>,
#  <span class="sortkey">Sauvage, Jean-Pierre</span>,
#  <span class="sortkey">Stoddart, Fraser</span>,
#  <span class="sortkey">Feringa, Ben</span>,
#  <span class="sortkey">Ohsumi, Yoshinori</span>,
#  <span class="sortkey">Dylan, Bob</span>,
#  <span class="sortkey">Santos, Juan Manuel</span>,
#  <span class="sortkey">Hart, Oliver</span>,
#  <span class="sortkey">Holmström, Bengt R.</span>,
#  <span class="sortkey">Weiss, Rainer</span>,
#  <span class="sortkey">Barish, Barry</span>,
#  <span class="sortkey">Thorne, Kip</span>,
#  <span class="sortkey">Dubochet, Jacques</span>,
#  <span class="sortkey">Frank, Joachim</span>,
#  <span class="sortkey">Henderson, Richard</span>,
#  <span class="sortkey">Hall, Jeffrey C.</span>,
#  <span class="sortkey">Rosbash, Michael</span>,
#  <span class="sortkey">Young, Michael W.</span>,
#  <span class="sortkey">Ishiguro, Kazuo</span>,
#  <span class="sortkey">Campaign to Abolish Nuclear Weapons, International</span>,
#  <span class="sortkey">Thaler, Richard</span>]

# %%
for tag in page.find_all("span", class_= "sortkey"):
    print(tag.text)
# Out:
# Röntgen, Wilhelm
# Hoff, Jacobus Henricus van 't
# von Behring, Emil Adolf
# Prudhomme, Sully
# Dunant, Henry
# Passy, Frédéric
# Lorentz, Hendrik
# Zeeman, Pieter
# Fischer, Hermann Emil
# Ross, Ronald
# Mommsen, Theodor
# Ducommun, Élie
# Gobat, Charles Albert
# Becquerel, Henri
# Curie, Pierre
# Curie, Marie
# Arrhenius, Svante
# Finsen, Niels Ryberg
# Bjørnson, Bjørnstjerne
# Cremer, Randal
# Rayleigh, Lord
# Ramsay, William
# Pavlov, Ivan
# Mistral, Frédéric
# Echegaray, José
# Lenard, Philipp
# Obama, Barack
# Ostrom, Elinor
# Williamson, Oliver E.
# Geim, Andre
# Novoselov, Konstantin
# Heck, Richard F.
# Negishi, Ei-ichi
# Suzuki, Akira
# Edwards, Robert G.
# Vargas Llosa, Mario
# Xiaobo, Liu
# Diamond, Peter A.
# Mortensen, Dale T.
# Pissarides, Christopher A.
# Perlmutter, Saul
# Riess, Adam G.
# Schmidt, Brian
# Shechtman, Dan
# Beutler, Bruce
# Hoffmann, Jules A.
# Steinman, Ralph M.
# Tranströmer, Tomas
# Sirleaf, Ellen Johnson
# Gbowee, Leymah
# Karman, Tawakel
# Sargent, Thomas J.
# Sims, Christopher A.
# Haroche, Serge
# J. Wineland, David
# Kobilka, Brian K.
# Lefkowitz, Robert J.
# Gurdon, John B.
# Yamanaka, Shinya
# Yan, Mo
# Union, European
# Roth, Alvin E.
# Shapley, Lloyd S.
# Englert, François
# Higgs, Peter W.
# Karplus, Martin
# Levitt, Michael
# Warshel, Arieh
# Rothman, James E.
# Schekman, Randy W.
# Südhof, Thomas C.
# Munro, Alice
# for the Prohibition of Chemical Weapons, Organisation
# Fama, Eugene F.
# Hansen, Lars Peter
# Shiller, Robert J.
# Akasaki, Isamu
# Amano, Hiroshi
# Nakamura, Shuji
# Betzig, Eric
# Hell, Stefan
# Moerner, William
# O'Keefe, John
# Moser, May-Britt
# Moser, Edvard
# Modiano, Patrick
# Satyarthi, Kailash
# Yousafzai, Malala
# Tirole, Jean
# Kajita, Takaaki
# McDonald, Arthur B.
# Lindahl, Tomas
# Modrich, Paul L.
# Sancar, Aziz
# Campbell, William C.
# Ōmura, Satoshi
# Youyou, Tu
# Alexievich, Svetlana
# National Dialogue Quartet, Tunisian
# Deaton, Angus
# J. Thouless, David
# Haldane, Duncan
# Kosterlitz, John M.
# Sauvage, Jean-Pierre
# Stoddart, Fraser
# Feringa, Ben
# Ohsumi, Yoshinori
# Dylan, Bob
# Santos, Juan Manuel
# Hart, Oliver
# Holmström, Bengt R.
# Weiss, Rainer
# Barish, Barry
# Thorne, Kip
# Dubochet, Jacques
# Frank, Joachim
# Henderson, Richard
# Hall, Jeffrey C.
# Rosbash, Michael
# Young, Michael W.
# Ishiguro, Kazuo
# Campaign to Abolish Nuclear Weapons, International
# Thaler, Richard

# %%
def extractInfo(name, path):
    print(path)
    base = 'https://en.wikipedia.org'
    url = base + path
    response = requests.get(base + path)
    page = BeautifulSoup(response.text, 'html.parser')
    birthday = page.find("span", class_="bday")
    nationality = page.find("td", class_="category")
    bdayText = birthday.text
    nationText = nationality.text
    return {"name":name, "birthday": bdayText, "nationality": nationText}

# %%
nobelListDict = []
for tag in page.find_all("span", class_ = "fn")[0:10]:
    print(tag.contents[0].attrs['title'])
    name = tag.contents[0].attrs['title']
    print(tag.contents[0].attrs['href'])
    path = tag.contents[0].attrs['href']
    nobelListDict.append(extractInfo(name, str(path)))
# Out:
# Wilhelm Röntgen
# /wiki/Wilhelm_R%C3%B6ntgen
# /wiki/Wilhelm_R%C3%B6ntgen
# Jacobus Henricus van 't Hoff
# /wiki/Jacobus_Henricus_van_%27t_Hoff
# /wiki/Jacobus_Henricus_van_%27t_Hoff
# Emil Adolf von Behring
# /wiki/Emil_Adolf_von_Behring
# /wiki/Emil_Adolf_von_Behring
# Sully Prudhomme
# /wiki/Sully_Prudhomme
# /wiki/Sully_Prudhomme
# Henry Dunant
# /wiki/Henry_Dunant
# /wiki/Henry_Dunant
# Frédéric Passy
# /wiki/Fr%C3%A9d%C3%A9ric_Passy
# /wiki/Fr%C3%A9d%C3%A9ric_Passy
# Hendrik Lorentz
# /wiki/Hendrik_Lorentz
# /wiki/Hendrik_Lorentz
# Pieter Zeeman
# /wiki/Pieter_Zeeman
# /wiki/Pieter_Zeeman
# Hermann Emil Fischer
# /wiki/Hermann_Emil_Fischer
# /wiki/Hermann_Emil_Fischer
# Ronald Ross
# /wiki/Ronald_Ross
# /wiki/Ronald_Ross

# %%
nobelListDict
# Out:
# [{'birthday': '1845-03-27',
#   'name': 'Wilhelm Röntgen',
#   'nationality': 'German[1]'},
#  {'birthday': '1852-08-30',
#   'name': "Jacobus Henricus van 't Hoff",
#   'nationality': 'Dutch'},
#  {'birthday': '1854-03-15',
#   'name': 'Emil Adolf von Behring',
#   'nationality': 'German'},
#  {'birthday': '1839-03-16',
#   'name': 'Sully Prudhomme',
#   'nationality': 'French'},
#  {'birthday': '1828-05-08', 'name': 'Henry Dunant', 'nationality': 'Swiss'},
#  {'birthday': '1822-05-20', 'name': 'Frédéric Passy', 'nationality': 'French'},
#  {'birthday': '1853-07-18',
#   'name': 'Hendrik Lorentz',
#   'nationality': 'Netherlands'},
#  {'birthday': '1865-05-25',
#   'name': 'Pieter Zeeman',
#   'nationality': 'Netherlands'},
#  {'birthday': '1852-10-09',
#   'name': 'Hermann Emil Fischer',
#   'nationality': 'Germany'},
#  {'birthday': '1857-05-13', 'name': 'Ronald Ross', 'nationality': 'British'}]

# %%
pd.DataFrame(nobelListDict)
# Out:
#      birthday                          name  nationality
# 0  1845-03-27               Wilhelm Röntgen    German[1]
# 1  1852-08-30  Jacobus Henricus van 't Hoff        Dutch
# 2  1854-03-15        Emil Adolf von Behring       German
# 3  1839-03-16               Sully Prudhomme       French
# 4  1828-05-08                  Henry Dunant        Swiss
# 5  1822-05-20                Frédéric Passy       French
# 6  1853-07-18               Hendrik Lorentz  Netherlands
# 7  1865-05-25                 Pieter Zeeman  Netherlands
# 8  1852-10-09          Hermann Emil Fischer      Germany
# 9  1857-05-13                   Ronald Ross      British

# %%
import re
pattern1 = re.compile("\d+")
pattern2 = re.compile("\d")
pattern3 = re.compile("\d?")
pattern4 = re.compile("\d*")

# %%
string = "abc123abc456"

# %%
pattern1.findall(string)[0]
# Out:
# '123'

# %%
pattern2.findall(string)
# Out:
# ['1', '2', '3', '4', '5', '6']

# %%
pattern3.findall(string)
# Out:
# ['', '', '', '1', '2', '3', '', '', '', '4', '5', '6', '']

# %%
pattern4.findall(string)
# Out:
# ['', '', '', '123', '', '', '', '456', '']
